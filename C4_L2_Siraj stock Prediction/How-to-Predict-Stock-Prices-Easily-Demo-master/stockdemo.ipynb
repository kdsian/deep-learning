# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
import lstm, time #helper libraries
# Out:
# Using TensorFlow backend.

# %%
#Step 1 Load Data
X_train, y_train, X_test, y_test = lstm.load_data('sp500.csv', 50, True)

# %%
#Step 2 Build Model
model = Sequential()

model.add(LSTM(
    input_dim=1,
    output_dim=50,
    return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(
    100,
    return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(
    output_dim=1))
model.add(Activation('linear'))

start = time.time()
model.compile(loss='mse', optimizer='rmsprop')
print('compilation time : ', time.time() - start)
# Out:
# compilation time :  0.03503012657165527

# %%
#Step 3 Train the model
model.fit(
    X_train,
    y_train,
    batch_size=512,
    nb_epoch=20,
    validation_split=0.05)
# Out:
# Train on 3523 samples, validate on 186 samples
# Epoch 1/20
# 3523/3523 [==============================] - 1s - loss: 5.8748e-04 - val_loss: 7.5774e-04
# Epoch 2/20
# 3523/3523 [==============================] - 1s - loss: 4.9162e-04 - val_loss: 6.0291e-04
# Epoch 3/20
# 3523/3523 [==============================] - 1s - loss: 4.9340e-04 - val_loss: 6.3653e-04
# Epoch 4/20
# 3523/3523 [==============================] - 1s - loss: 4.8221e-04 - val_loss: 6.2297e-04
# Epoch 5/20
# 3523/3523 [==============================] - 1s - loss: 4.2464e-04 - val_loss: 5.5283e-04
# Epoch 6/20
# 3523/3523 [==============================] - 1s - loss: 4.4153e-04 - val_loss: 5.1870e-04
# Epoch 7/20
# 3523/3523 [==============================] - 1s - loss: 3.8788e-04 - val_loss: 4.8385e-04
# Epoch 8/20
# 3523/3523 [==============================] - 1s - loss: 3.7786e-04 - val_loss: 5.7537e-04
# Epoch 9/20
# 3523/3523 [==============================] - 1s - loss: 3.8004e-04 - val_loss: 4.7749e-04
# Epoch 10/20
# 3523/3523 [==============================] - 1s - loss: 4.0465e-04 - val_loss: 4.4294e-04
# Epoch 11/20
# 3523/3523 [==============================] - 1s - loss: 3.3898e-04 - val_loss: 5.2938e-04
# Epoch 12/20
# 3523/3523 [==============================] - 1s - loss: 3.6042e-04 - val_loss: 3.7958e-04
# Epoch 13/20
# 3523/3523 [==============================] - 1s - loss: 3.4071e-04 - val_loss: 4.0774e-04
# Epoch 14/20
# 3523/3523 [==============================] - 1s - loss: 3.6804e-04 - val_loss: 3.5635e-04
# Epoch 15/20
# 3523/3523 [==============================] - 1s - loss: 2.8477e-04 - val_loss: 3.9789e-04
# Epoch 16/20
# 3523/3523 [==============================] - 1s - loss: 3.3693e-04 - val_loss: 4.0742e-04
# Epoch 17/20
# 3523/3523 [==============================] - 1s - loss: 3.1326e-04 - val_loss: 4.3327e-04
# Epoch 18/20
# 3523/3523 [==============================] - 1s - loss: 2.9987e-04 - val_loss: 3.9338e-04
# Epoch 19/20
# 3523/3523 [==============================] - 1s - loss: 3.0842e-04 - val_loss: 4.0527e-04
# Epoch 20/20
# 3523/3523 [==============================] - 1s - loss: 2.7977e-04 - val_loss: 3.3273e-04

# %%
#Step 4 - Plot the predictions!
predictions = lstm.predict_sequences_multiple(model, X_test, 50, 50)
lstm.plot_results_multiple(predictions, y_test, 50)
# Out:
# yo

# %%
int()
# Out:
# 0
